# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from mlxtend.plotting import plot_decision_regions

# %%
df = pd.read_csv('modified_placement_data.csv')

# %%
df.head()
# Out:
#   cgpa     iq placement
# 0  6,8  123.0       Yes
# 1  5,9  106.0        No
# 2  5,3  121.0        No
# 3  7,4  132.0       Yes
# 4  5,8  142.0        No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       95 non-null     object
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 2.5+ KB

# %%
df.isnull().sum()
# Out:
# cgpa         5
# iq           0
# placement    0
# dtype: int64

# %%
df['cgpa'] = df['cgpa'].fillna(5)

# %%
# Steps:
#1.Preprocess + EDA + Feature Engineering
#2.Extract input and output cols
#3.Scale the Values
#4.Train Test Split
#5.Evluate the model
#6.Deploy the model

# %%
df['cgpa'] = df['cgpa'].astype(str).str.replace(',', '.', regex=False)
df['cgpa'] = df['cgpa'].astype(float)

# %%
plt.scatter(df['cgpa'],df['iq'])

# %%
X = df.iloc[:,0:2]
Y = df.iloc[:,-1]

# %%
le = LabelEncoder()
categorical_col = [
    "placement"
]
for col in categorical_col:
    df[col] = le.fit_transform(df[col])

# %%
print(X)
# Out:
# [[  6.8 123. ]
#  [  5.9 106. ]
#  [  5.3 121. ]
#  [  7.4 132. ]
#  [  5.8 142. ]
#  [  7.1  48. ]
#  [  5.7 143. ]
#  [  5.   63. ]
#  [  6.1 156. ]
#  [  5.   66. ]
#  [  6.   45. ]
#  [  6.9 138. ]
#  [  5.4 139. ]
#  [  6.4 116. ]
#  [  6.1 103. ]
#  [  5.1 176. ]
#  [  5.2 224. ]
#  [  3.3 183. ]
#  [  4.  100. ]
#  [  5.2 132. ]
#  [  6.6 120. ]
#  [  7.1 151. ]
#  [  4.9 120. ]
#  [  4.7  87. ]
#  [  4.7 121. ]
#  [  5.   91. ]
#  [  7.  199. ]
#  [  6.  124. ]
#  [  5.2  90. ]
#  [  7.  112. ]
#  [  7.6 128. ]
#  [  3.9 109. ]
#  [  7.  139. ]
#  [  6.  149. ]
#  [  4.8 163. ]
#  [  6.8  90. ]
#  [  5.7 140. ]
#  [  8.1 149. ]
#  [  6.5 160. ]
#  [  4.6 146. ]
#  [  4.9 134. ]
#  [  5.4 114. ]
#  [  7.6  89. ]
#  [  6.8 141. ]
#  [  7.5  61. ]
#  [  6.   66. ]
#  [  5.3 114. ]
#  [  5.2 161. ]
#  [  6.6 138. ]
#  [  5.4 135. ]
#  [  3.5 233. ]
#  [  4.8 141. ]
#  [  7.  175. ]
#  [  8.3 168. ]
#  [  5.  141. ]
#  [  7.8 114. ]
#  [  6.1  65. ]
#  [  6.5 130. ]
# ...

# %%
print(Y)
# Out:
# ['Yes' 'No' 'No' 'Yes' 'No' 'Yes' 'No' 'No' 'No' 'No' 'Yes' 'Yes' 'No'
#  'Yes' 'No' 'No' 'No' 'No' 'No' 'No' 'Yes' 'Yes' 'No' 'No' 'No' 'No' 'Yes'
#  'Yes' 'No' 'Yes' 'Yes' 'No' 'Yes' 'No' 'No' 'Yes' 'No' 'Yes' 'Yes' 'No'
#  'No' 'No' 'Yes' 'Yes' 'Yes' 'Yes' 'No' 'No' 'Yes' 'No' 'No' 'No' 'Yes'
#  'Yes' 'Yes' 'Yes' 'No' 'Yes' 'Yes' 'No' 'Yes' 'Yes' 'No' 'Yes' 'Yes'
#  'Yes' 'Yes' 'No' 'No' 'Yes' 'Yes' 'Yes' 'Yes' 'No' 'Yes' 'No' 'No' 'Yes'
#  'No' 'Yes' 'No' 'No' 'Yes' 'Yes' 'No' 'Yes' 'No' 'Yes' 'No' 'No' 'Yes'
#  'Yes' 'No' 'Yes' 'No' 'No' 'No' 'Yes' 'Yes' 'Yes']

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.1, random_state=42)

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-1.68116434e+00, -6.20298481e-01],
#        [ 1.50233798e+00,  9.80618923e-02],
#        [-8.85288761e-01, -1.62087186e+00],
#        [ 8.74480574e-02,  6.36832173e-01],
#        [ 1.23704612e+00, -9.79478668e-01],
#        [-8.94131823e-02,  4.57242079e-01],
#        [-8.85288761e-01,  7.90766538e-01],
#        [ 1.23704612e+00, -1.90308486e+00],
#        [-4.43135662e-01,  3.80274896e-01],
#        [-1.76959496e+00, -3.89396933e-01],
#        [ 1.67919922e+00, -2.61118295e-01],
#        [-1.32744186e+00,  6.36832173e-01],
#        [ 9.71754256e-01,  1.91961855e+00],
#        [ 1.50233798e+00, -9.02511485e-01],
#        [ 2.29821355e+00, -1.07183929e-01],
#        [-7.08427521e-01,  1.32953682e+00],
#        [-8.85288761e-01,  2.51996258e-01],
#        [-1.32744186e+00, -2.10833068e+00],
#        [-7.96858141e-01, -1.49259322e+00],
#        [ 1.23704612e+00, -2.09806839e-01],
#        [ 8.83323636e-01,  3.54619169e-01],
#        [-6.19996902e-01,  9.44700904e-01],
# ...

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 1.41390736,  0.14937335],
#        [ 2.12135231,  1.124291  ],
#        [ 0.35273992,  0.07240616],
#        [ 0.08744806, -1.49259322],
#        [ 1.41390736, -1.62087186],
#        [-1.15058062,  0.55986499],
#        [-0.88528876, -0.10718393],
#        [-0.88528876,  1.84265137],
#        [ 0.08744806, -2.0313635 ],
#        [ 0.79489302, -0.03021675]])

# %%
Lr = LogisticRegression()

# %%
Lr.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred = Lr.predict(X_test)

# %%
Y_test
# Out:
# array(['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes'],
#       dtype=object)

# %%
accuracy_score(Y_pred,Y_test)
# Out:
# 0.8

# %%
print(type(X))
print(type(Y))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(type(X))
print(type(Y))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
# Plot(What the pattern model learn)
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(X, Y, clf=Lr, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(Lr,open('placement.pickle','wb'))
